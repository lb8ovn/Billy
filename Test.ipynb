# %% [markdown]
# <a href="https://colab.research.google.com/github/lb8ovn/Billy/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""https://github.com/lb8ovn/colabtest/blob/master/Test.ipynb"""
import matplotlib.pyplot as plt
x=[1,2]
y=[2,4]
plt.plot(x,y)
plt.show()
